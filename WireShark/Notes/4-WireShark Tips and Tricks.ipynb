# %% [markdown]
# #Easy Filters
#
# > Select the packet > right click > apply as a filter

# %% [markdown]
# #Profiles in WireShark
#
# > Profiles are used to save the look of wireshark just like workspaces in illustrator
#
# > https://www.cellstream.com/resources/wireshark-profiles-repository for community filters

# %% [markdown]
# #Conversation Filters
#
# > right click > conversation filter > ...

# %% [markdown]
# #Statistics
#
# > Go to Statistics Tab
#
# > Choose desired Statistic
#
# > 'endpoint' option to know device ips and MAC involved in that capture
#
# > 'Protocol Hierarchy' for distribution of captured Packets

# %% [markdown]
# #Conversations and IO Graph
#
# > Ip to Ip Conversational stats
#
# > IO Graph to look at streamed data graph

# %% [markdown]
# #Flow Graph
#
# > to look at how traffic flows

# %% [markdown]
# #Tshark is a command line WireShark
#
# > will be potential when the device used to capture traffic is a stelth device like raspberry-pie
#
# > tshar as terminal UI version termshark
